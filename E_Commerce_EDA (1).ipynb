# %%
import pandas as pd
df=pd.read_csv("olist_customers_dataset.csv")

# %%
df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
df1=df
df1
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
df_customers=df1

# %%
df_customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
df=pd.read_csv("olist_orders_dataset.csv")

# %%
df_orders=df

# %%
df_payments=pd.read_csv("olist_order_payments_dataset.csv")

# %%
df_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
orders=df_orders

# %%
print(customers.shape)
print(orders.shape)
print(payments.shape)
# Out:
# (99441, 5)
# (99441, 8)
# (103886, 5)

# %%
orders["customer_id"].nunique()
# Out:
# 99441

# %%
customers["customer_id"].nunique()
# Out:
# 99441

# %%
customers["customer_unique_id"].nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'customer_unique_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ...

# %%
orders["order_id"].nunique()

# %%
customer_orders=pd.merge(left=customers,right=orders,on="customer_id",how="inner")

# %%
customer_orders
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state  \
# ...

# %%
customer_orders.dtypes
# Out:
# customer_id                      object
# customer_unique_id               object
# customer_zip_code_prefix          int64
# customer_city                    object
# customer_state                   object
# order_id                         object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object

# %%
date_cols=["order_delivered_carrier_date",
"order_delivered_customer_date",
"order_estimated_delivery_date",
"order_approved_at",
"order_purchase_timestamp"]
customers.columns
orders.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %%
customers.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
for cols in date_col:
    customer_orders[cols]=pd.to_datetime(customer_orders[cols])

# %%
customer_orders.dtypes
# Out:
# customer_id                              object
# customer_unique_id                       object
# customer_zip_code_prefix                  int64
# customer_city                            object
# customer_state                           object
# order_id                                 object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
customer_orders.shape
# Out:
# (99441, 12)

# %%
customer_orders["order_status"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 customer_orders["order_status"].value_counts()
#
# NameError: name 'customer_orders' is not defined

# %%
customer_orders["year_month"]=customer_orders["order_purchase_timestamp"].dt.to_period("M")

# %%
customer_orders
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state  \
# ...

# %%
customer_orders["year_month"].value_counts()
# Out:
# year_month
# 2017-11    7544
# 2018-01    7269
# 2018-03    7211
# 2018-04    6939
# 2018-05    6873
# 2018-02    6728
# 2018-08    6512
# 2018-07    6292
# 2018-06    6167
# 2017-12    5673
# 2017-10    4631
# 2017-08    4331
# 2017-09    4285
# 2017-07    4026
# 2017-05    3700
# 2017-06    3245
# 2017-03    2682
# 2017-04    2404
# 2017-02    1780
# 2017-01     800
# 2016-10     324
# 2018-09      16
# 2016-09       4
# 2018-10       4
# 2016-12       1
# Freq: M, Name: count, dtype: int64

# %%
payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
payments.groupby("order_id").size().value_counts()
# Out:
# 1     96479
# 2      2382
# 3       301
# 4       108
# 5        52
# 6        36
# 7        28
# 8        11
# 9         9
# 11        8
# 12        8
# 10        5
# 13        3
# 15        2
# 14        2
# 19        2
# 22        1
# 21        1
# 26        1
# 29        1
# Name: count, dtype: int64

# %%
payment_summary=payments.groupby("order_id").agg({"payment_value":"sum"})

# %%
payment_summary.reset_index()
# Out:
#                                order_id  payment_value
# 0      00010242fe8c5a6d1ba2dd792cb16214          72.19
# 1      00018f77f2f0320c557190d7a144bdd3         259.83
# 2      000229ec398224ef6ca0657da4fc703e         216.87
# 3      00024acbcdf0a6daa1e931b038114c75          25.78
# 4      00042b26cf59d7ce69dfabb4e55b4fd9         218.04
# ...                                 ...            ...
# 99435  fffc94f6ce00a00581880bf54a75a037         343.40
# 99436  fffcd46ef2263f404302a634eb57f7eb         386.53
# 99437  fffce4705a9662cd70adb13d4a31832d         116.85
# 99438  fffe18544ffabc95dfada21779c9644f          64.71
# 99439  fffe41c64501cc87c801fd61db3f6244          55.79
#
# [99440 rows x 2 columns]

# %%
customer_order_payment=pd.merge(left=customer_orders,right=payment_summary,on="order_id",how="left")

# %%
customer_order_payment.isnull().sum()
# Out:
# customer_id                         0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# order_id                            0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# year_month                          0
# payment_value                       1
# dtype: int64

# %%
customer_order_payment[customer_order_payment["order_delivered_customer_date"].isnull()]["order_status"].value_counts()
# Out:
# order_status
# shipped        1107
# canceled        619
# unavailable     609
# invoiced        314
# processing      301
# delivered         8
# created           5
# approved          2
# Name: count, dtype: int64

# %%
customer_order_payment["order_id"].nunique()
# Out:
# 99441

# %%
customer_order_payment.shape
# Out:
# (99441, 14)

# %%
customer_order_payment.to_csv("customer_order_payment.csv",index=False)

# %%
order_items=pd.read_csv("olist_order_items_dataset.csv")

# %%
products=pd.read_csv("olist_products_dataset.csv")

# %%
order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
order_items.groupby("order_id").size().value_counts()
# Out:
# 1     88863
# 2      7516
# 3      1322
# 4       505
# 5       204
# 6       198
# 7        22
# 8         8
# 10        8
# 12        5
# 11        4
# 9         3
# 15        2
# 14        2
# 20        2
# 13        1
# 21        1
# Name: count, dtype: int64

# %%
order_items.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')

# %%
products.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')

# %%
product_sales=pd.merge(left=order_items,right=products,on="product_id",how="left")

# %%
product_sales
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
product_sales.isnull().sum()
# Out:
# order_id                         0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# product_category_name         1603
# product_name_lenght           1603
# product_description_lenght    1603
# product_photos_qty            1603
# product_weight_g                18
# product_length_cm               18
# product_height_cm               18
# product_width_cm                18
# dtype: int64

# %%
products.shape
# Out:
# (32951, 9)

# %%
order_items["product_id"].nunique()
# Out:
# 32951

# %% [raw]
# order_items.shape

# %%
order_items.shape
# Out:
# (112650, 7)

# %%
import numpy as np
product_sales=product_sales.fillna("unknown")

# %%
product_sales[product_sales["product_category_name"]=="unknown"]
# Out:
#                                 order_id  order_item_id  \
# 123     0046e1d57f4c07c8c92ab26be8c3dfc0              1
# 125     00482f2670787292280e0a8153d82467              1
# 132     004f5d8f238e8908e6864b874eda3391              1
# 142     0057199db02d1a5ef41bacbf41f8f63b              1
# 171     006cb7cafc99b29548d4f412c7f9f493              1
# ...                                  ...            ...
# 112306  ff24fec69b7f3d30f9dc1ab3aee7c179              1
# 112333  ff3024474be86400847879103757d1fd              1
# 112350  ff3a45ee744a7c1f8096d2e72c1a23e4              1
# 112438  ff7b636282b98e0aa524264b295ed928              1
# 112501  ffa5e4c604dea4f0a59d19cc2322ac19              2
#
#                               product_id                         seller_id  \
# 123     ff6caf9340512b8bf6d2a2a6df032cfa  38e6dada03429a47197d5d584d793b41
# 125     a9c404971d1a5b1cbc2e4070e02731fd  702835e4b785b67a084280efca355756
# ...

# %%
product_sales[(product_sales=="unknown").any(axis=1)]
# Out:
#                                 order_id  order_item_id  \
# 123     0046e1d57f4c07c8c92ab26be8c3dfc0              1
# 125     00482f2670787292280e0a8153d82467              1
# 132     004f5d8f238e8908e6864b874eda3391              1
# 142     0057199db02d1a5ef41bacbf41f8f63b              1
# 171     006cb7cafc99b29548d4f412c7f9f493              1
# ...                                  ...            ...
# 112306  ff24fec69b7f3d30f9dc1ab3aee7c179              1
# 112333  ff3024474be86400847879103757d1fd              1
# 112350  ff3a45ee744a7c1f8096d2e72c1a23e4              1
# 112438  ff7b636282b98e0aa524264b295ed928              1
# 112501  ffa5e4c604dea4f0a59d19cc2322ac19              2
#
#                               product_id                         seller_id  \
# 123     ff6caf9340512b8bf6d2a2a6df032cfa  38e6dada03429a47197d5d584d793b41
# 125     a9c404971d1a5b1cbc2e4070e02731fd  702835e4b785b67a084280efca355756
# ...

# %%
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
product_sales_orders=pd.merge(left=product_sales,right=orders,on="order_id",how="left")

# %%
product_sales_orders.dtypes
# Out:
# order_id                          object
# order_item_id                      int64
# product_id                        object
# seller_id                         object
# shipping_limit_date               object
# price                            float64
# freight_value                    float64
# product_category_name             object
# product_name_lenght               object
# product_description_lenght        object
# product_photos_qty                object
# product_weight_g                  object
# product_length_cm                 object
# product_height_cm                 object
# product_width_cm                  object
# customer_id                       object
# order_status                      object
# order_purchase_timestamp          object
# order_approved_at                 object
# order_delivered_carrier_date      object
# order_delivered_customer_date     object
# order_estimated_delivery_date     object
# dtype: object

# %%
date_cols=["shipping_limit_date","order_purchase_timestamp",
"order_approved_at" ,                
"order_delivered_carrier_date",      
"order_delivered_customer_date",     
"order_estimated_delivery_date"]

# %%
for cols in date_cols:
    product_sales_orders[cols]=pd.to_datetime(product_sales_orders[cols])

# %%
product_sales_orders.dtypes
# Out:
# order_id                                 object
# order_item_id                             int64
# product_id                               object
# seller_id                                object
# shipping_limit_date              datetime64[ns]
# price                                   float64
# freight_value                           float64
# product_category_name                    object
# product_name_lenght                      object
# product_description_lenght               object
# product_photos_qty                       object
# product_weight_g                         object
# product_length_cm                        object
# product_height_cm                        object
# product_width_cm                         object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# ...

# %%
product_sales_orders=product_sales_orders.drop(columns=[
    'order_item_id',
    'shipping_limit_date',

    'product_name_lenght',
    'product_description_lenght',
    'product_photos_qty',

    'customer_id',

    'order_approved_at',
    'order_delivered_carrier_date',

    'product_length_cm',
    'product_height_cm',
    'product_width_cm'
])

# %%
product_sales_orders
# Out:
#                                 order_id                        product_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2       000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3       00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                  ...                               ...
# 112645  fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# 112646  fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# 112647  fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# 112648  fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# 112649  fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
#                                seller_id   price  freight_value  \
# ...

# %%
product_sales_orders.shape
# Out:
# (112650, 11)

# %%
product_sales_orders.isnull().sum()
# Out:
# order_id                            0
# product_id                          0
# seller_id                           0
# price                               0
# freight_value                       0
# product_category_name               0
# product_weight_g                    0
# order_status                        0
# order_purchase_timestamp            0
# order_delivered_customer_date    2454
# order_estimated_delivery_date       0
# dtype: int64

# %%
product_sales_orders[product_sales_orders["order_delivered_customer_date"].isnull()]["order_status"].value_counts()
# Out:
# order_status
# shipped        1185
# canceled        535
# invoiced        359
# processing      357
# delivered         8
# unavailable       7
# approved          3
# Name: count, dtype: int64

# %%
product_sales_orders.to_csv("product_sales_orders.csv",index=False)

# %%
translation=pd.read_csv("product_category_name_translation.csv")

# %%
translation
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
product_sales_orders=pd.merge(left=product_sales_orders,right=translation,on="product_category_name",how="left")

# %% [raw]
# product_sales_orders

# %%
product_sales_orders=product_sales_orders.drop(columns="product_category_name")

# %%
product_sales_orders.columns
# Out:
# Index(['order_id', 'product_id', 'seller_id', 'price', 'freight_value',
#        'product_weight_g', 'order_status', 'order_purchase_timestamp',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'product_category_name_english'],
#       dtype='object')

# %%
product_sales_orders.columns=['order_id', 'product_id', 'seller_id', 'price', 'freight_value',
       'product_weight_g', 'order_status', 'order_purchase_timestamp',
       'order_delivered_customer_date', 'order_estimated_delivery_date',
       'product_category']

# %%
product_sales_orders
# Out:
#                                 order_id                        product_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2       000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3       00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                  ...                               ...
# 112645  fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# 112646  fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# 112647  fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# 112648  fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# 112649  fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
#                                seller_id   price  freight_value  \
# ...

# %%
product_sales_orders.to_csv("product_sales_orders.csv",index=False)

# %%
sellers=pd.read_csv("olist_sellers_dataset.csv")

# %%
sellers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
sellers.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
product_sales_orders=pd.merge(left=product_sales_orders,right=sellers,on="seller_id",how="left")

# %%
product_sales_orders
# Out:
#                                 order_id                        product_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2       000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3       00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                  ...                               ...
# 112645  fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# 112646  fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# 112647  fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# 112648  fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# 112649  fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
#                                seller_id   price  freight_value  \
# ...

# %%
product_sales_orders=product_sales_orders.drop(columns="seller_zip_code_prefix")

# %%
product_sales_orders.to_csv("product_sales_orders.csv",index=False)

# %%
customer_order_payment
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state  \
# ...

# %%
customer_order_payment=customer_order_payment.drop(columns="customer_zip_code_prefix")

# %%
customer_order_payment.to_csv("customer_order_payment.csv",index=False)

# %%
import pandas as pd
reviews=pd.read_csv("olist_order_reviews_dataset.csv")

# %%
reviews.isnull().sum()
# Out:
# review_id               0
# order_id                0
# review_score            0
# review_creation_date    0
# dtype: int64

# %%
reviews.columns
# Out:
# Index(['review_id', 'order_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp'],
#       dtype='object')

# %%
reviews=reviews.drop(columns=['review_comment_title',
       'review_comment_message','review_answer_timestamp'])

# %%
reviews.dtypes
# Out:
# review_id                       object
# order_id                        object
# review_score                     int64
# review_creation_date    datetime64[ns]
# dtype: object

# %%
reviews["review_creation_date"]=pd.to_datetime(reviews["review_creation_date"])

# %%
reviews.shape
# Out:
# (99224, 4)

# %%
orders.shape
# Out:
# (99441, 8)

# %%
orders['order_id'].nunique()
# Out:
# 99441

# %%
reviews['order_id'].nunique()
# Out:
# 98673

# %%
reviews.groupby("order_id").size().value_counts()
# Out:
# 1    98126
# 2      543
# 3        4
# Name: count, dtype: int64

# %%
review_1=reviews[reviews['order_id'].duplicated(keep=False)]

# %%
review_1.sort_values("order_id")
# Out:
#                               review_id                          order_id  \
# 25612  89a02c45c340aeeb1354a24e7d4b2c1e  0035246a40f520710769010f752e7507
# 22423  2a74b0559eb58fc1ff842ecc999594cb  0035246a40f520710769010f752e7507
# 22779  ab30810c29da5da8045216f0f62652a2  013056cfe49763c6f66bda03396c5ee3
# 68633  73413b847f63e02bc752b364f6d05ee9  013056cfe49763c6f66bda03396c5ee3
# 854    830636803620cdf8b6ffaf1b2f6e92b2  0176a6846bcb3b0d3aa3116a9a768597
# ...                                 ...                               ...
# 27465  5e78482ee783451be6026e5cf0c72de1  ff763b73e473d03c321bcd5a053316e8
# 41355  39de8ad3a1a494fc68cc2d5382f052f4  ff850ba359507b996e8b2fbb26df8d03
# 18783  80f25f32c00540d49d57796fb6658535  ff850ba359507b996e8b2fbb26df8d03
# 92230  870d856a4873d3a67252b0c51d79b950  ffaabba06c9d293a3c614e0515ddbabc
# 53962  5476dd0eaee7c4e2725cafb011aa758c  ffaabba06c9d293a3c614e0515ddbabc
#
#        review_score review_creation_date
# ...

# %%
review=reviews.groupby("order_id").agg({"review_score":"mean","review_creation_date":"max"})

# %%
review=review.reset_index()

# %%
review
# Out:
#                                order_id  review_score review_creation_date
# 0      00010242fe8c5a6d1ba2dd792cb16214           5.0           2017-09-21
# 1      00018f77f2f0320c557190d7a144bdd3           4.0           2017-05-13
# 2      000229ec398224ef6ca0657da4fc703e           5.0           2018-01-23
# 3      00024acbcdf0a6daa1e931b038114c75           4.0           2018-08-15
# 4      00042b26cf59d7ce69dfabb4e55b4fd9           5.0           2017-03-02
# ...                                 ...           ...                  ...
# 98668  fffc94f6ce00a00581880bf54a75a037           5.0           2018-05-11
# 98669  fffcd46ef2263f404302a634eb57f7eb           5.0           2018-07-24
# 98670  fffce4705a9662cd70adb13d4a31832d           5.0           2017-10-29
# 98671  fffe18544ffabc95dfada21779c9644f           5.0           2017-08-17
# 98672  fffe41c64501cc87c801fd61db3f6244           5.0           2018-06-15
#
# [98673 rows x 3 columns]

# %%
review_orders=pd.merge(left=orders,right=review,on="order_id",how="left")

# %%
review_orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# review_score                      768
# review_creation_date              768
# dtype: int64

# %%
review_orders.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp                 object
# order_approved_at                        object
# order_delivered_carrier_date             object
# order_delivered_customer_date            object
# order_estimated_delivery_date            object
# review_score                            float64
# review_creation_date             datetime64[ns]
# dtype: object

# %%
df_cols=["order_purchase_timestamp",                 
"order_approved_at",                        
"order_delivered_carrier_date",             
"order_delivered_customer_date",            
"order_estimated_delivery_date"]

for cols in df_cols:
    review_orders[cols]=pd.to_datetime(review_orders[cols])

# %%
review_orders.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# review_score                            float64
# review_creation_date             datetime64[ns]
# dtype: object

# %%
customers=pd.read_csv("olist_customers_dataset.csv")

# %%
customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
review_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
review_orders["customer_id"].nunique()
# Out:
# 99441

# %%
customers["customer_id"].nunique()
# Out:
# 99441

# %%
review_order_customer=pd.merge(left=review_orders,right=customers,on="customer_id",how="left")

# %%
review_order_customer.drop(columns=["customer_id"],inplace=True)

# %%
review_order_customer.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# review_score                      768
# review_creation_date              768
# customer_unique_id                  0
# customer_city                       0
# customer_state                      0
# dtype: int64

# %%
review_order_customer
# Out:
#                                order_id order_status order_purchase_timestamp  \
# 0      e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 1      53cdb2fc8bc7dce0b6741e2150273451    delivered      2018-07-24 20:41:37
# 2      47770eb9100c2d0c44946d9cf07ec65d    delivered      2018-08-08 08:38:49
# 3      949d5b44dbf5de918fe9c16f97b45f8a    delivered      2017-11-18 19:28:06
# 4      ad21c59c0840e6cb83a9ceb5573f8159    delivered      2018-02-13 21:18:39
# ...                                 ...          ...                      ...
# 99436  9c5dedf39a927c1b2549525ed64a053c    delivered      2017-03-09 09:54:05
# 99437  63943bddc261676b46f01ca7ac2f7bd8    delivered      2018-02-06 12:58:58
# 99438  83c1379a015df1e13d02aae0204711ab    delivered      2017-08-27 14:46:43
# 99439  11c177c8e97725db2631073c19f07b62    delivered      2018-01-08 21:28:27
# 99440  66dea50a8b16d9b4dee7af250b4be1a5    delivered      2018-03-08 20:57:30
#
# ...

# %%
review_order_customer.to_csv("review_order_customer.csv",index=False)

# %%
df=pd.read_csv("customer_"customer_order_paymentorder_payment.csv")

# %%
customer_order_payment=customer_order_payment.drop(columns="customer_id")

# %%
customer_order_payment.to_csv("customer_order_payment.csv",index=False)

# %%
import pandas as pd 
df=pd.read_csv("customer_order_payment.csv")

# %%
df.columns
# Out:
# Index(['customer_unique_id', 'customer_city', 'customer_state', 'order_id',
#        'order_status', 'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'year_month', 'payment_value'],
#       dtype='object')

# %%
import pymysql
print("PyMySQL Installed")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pymysql
#       2 print("PyMySQL Installed")
#
# ModuleNotFoundError: No module named 'pymysql'

# %%
# !pip install pymysql sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pymysql
import sqlalchemy

print("Both Installed")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import pymysql
#       2 import sqlalchemy
#       4 print("Both Installed")
#
# ModuleNotFoundError: No module named 'pymysql'

# %%
import sys
print(sys.executable)
# Out:
# C:\ProgramData\anaconda3\python.exe

# %%
import sys
# !{sys.executable} -m pip install pymysql sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pymysql
import sqlalchemy

print("Both Installed")
# Out:
# Both Installed

# %%
import sys
print(sys.executable)
# Out:
# C:\ProgramData\anaconda3\python.exe

# %%
import sys
# !{sys.executable} -m pip install pymysql sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pymysql
import sqlalchemy

print("Both Installed")
# Out:
# Both Installed

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://root:@localhost/project_vacation"
)

print("Connection Created")
# Out:
# Connection Created

# %%
with engine.connect() as conn:
    print("Connected Successfully")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3301, in Engine.raw_connection(self)
#    3280 """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282 The returned object is a proxied version of the DBAPI
#    (...)   3299
#    3300 """
# -> 3301 return self.pool.connect()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     440 """Return a DBAPI connection from the pool.
#     441
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://root:SANIDHYA@localhost/project_vacation"
)

with engine.connect() as conn:
    print("Connected Successfully")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3301, in Engine.raw_connection(self)
#    3280 """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282 The returned object is a proxied version of the DBAPI
#    (...)   3299
#    3300 """
# -> 3301 return self.pool.connect()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     440 """Return a DBAPI connection from the pool.
#     441
# ...

# %%
product_sales_orders.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 product_sales_orders.duplicated().sum()
#
# NameError: name 'product_sales_orders' is not defined

# %%
import pandas as pd 
df=pd.read_csv("product_sales_orders.csv")

# %%
df.duplicated().sum()
# Out:
# np.int64(10225)
